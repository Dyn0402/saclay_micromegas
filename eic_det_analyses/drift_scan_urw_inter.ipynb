# %%
import numpy as np
import matplotlib.pyplot as plt
import os
import platform

from Detector_Classes.DetectorConfigLoader import DetectorConfigLoader
from Detector_Classes.DreamDetector import DreamDetector

# %%
# Check if platform is Windows or Linux
if platform.system() == 'Windows':
    base_dir = 'F:/Saclay/cosmic_data/'
    det_type_info_dir = 'C:/Users/Dylan/PycharmProjects/Cosmic_Bench_DAQ_Control/config/detectors/'
    out_dir = 'F:/Saclay/Analysis/Cosmic Bench/11-5-24/'
    chunk_size = 100  # Number of files to process at once
elif platform.system() == 'Linux':
    base_dir = '/local/home/dn277127/Bureau/cosmic_data/'
    det_type_info_dir = '/local/home/dn277127/PycharmProjects/Cosmic_Bench_DAQ_Control/config/detectors/'
    out_dir = '/local/home/dn277127/Bureau/cosmic_data/Analysis/11-15-24/'
    chunk_size = 7  # Number of files to process at once
else:
    raise OSError('Unknown platform')

# %%
run_name = 'drift_scan_11-13-24'
run_dir = f'{base_dir}{run_name}/'

detector = 'urw_inter'
drift_vs = [800, 750, 700, 650, 600, 550, 500, 450, 400, 350, 300, 250, 200, 150, 100, 50]

# file_nums = list(range(0, 1))
file_nums = 'all'


run_json_path = f'{run_dir}run_config.json'

try:
    os.mkdir(out_dir)
except FileExistsError:
    pass

# %%
det_config_loader = DetectorConfigLoader(run_json_path, det_type_info_dir)

# %%
sigmas_x, sigma_x_errs = [], []
sigmas_y, sigma_y_errs = [], []
for v in drift_vs:
    sub_run_name = f'drift_{v}'
    data_dir = f'{run_dir}{sub_run_name}/filtered_root/'
    ped_dir = f'{run_dir}{sub_run_name}/decoded_root/'
    det_config = det_config_loader.get_det_config(detector, sub_run_name=sub_run_name)
    det = DreamDetector(config=det_config)
    det.load_dream_data(data_dir, ped_dir, 10, file_nums, chunk_size, save_waveforms=False, waveform_fit_func='parabola_vectorized')
    det.dream_data.correct_for_fine_timestamps()
    
    sigma_x, sigma_x_err = det.dream_data.plot_event_time_maxes(max_channel=True, channels=np.arange(0, int(256 / 2)), min_amp=None, plot=True)
    plt.title(f'Time of Max for {detector} X Strips Drift Voltage: {v}V')
    sigmas_x.append(sigma_x)
    sigma_x_errs.append(sigma_x_err)
    
    sigma_y, sigma_y_err = det.dream_data.plot_event_time_maxes(max_channel=True, channels=np.arange(int(256 / 2), 256), min_amp=None, plot=True)
    plt.title(f'Time of Max for {detector} Y Strips Drift Voltage: {v}V')
    sigmas_y.append(sigma_y)
    sigma_y_errs.append(sigma_y_err)
# Out:
# Reading in data...
#  14%|█▍        | 1/7 [00:01<00:10,  1.68s/it]
# data_i shape: (1153, 256, 32)
#  29%|██▊       | 2/7 [00:03<00:08,  1.72s/it]
# data_i shape: (2245, 256, 32)
# data_i shape: (2186, 256, 32)
# data_i shape: (2078, 256, 32)
# data_i shape: (2163, 256, 32)
# 100%|██████████| 7/7 [00:03<00:00,  1.86it/s]
# data_i shape: (2311, 256, 32)
# data_i shape: (2267, 256, 32)
# Read in data shape: (14403, 256, 32)
# Getting amplitudes...
# 100%|██████████| 7/7 [00:00<00:00, 13.92it/s]
# Fitting time: 0.5667083263397217 s
# Processed chunk 1/2
# 100%|██████████| 1/1 [00:01<00:00,  1.35s/it]
# data_i shape: (2266, 256, 32)
# Read in data shape: (2266, 256, 32)
# Getting amplitudes...
# 100%|██████████| 7/7 [00:00<00:00, 146.31it/s]
# Fitting time: 0.10208630561828613 s
# Processed chunk 2/2
# Getting hits...
# Reading in data...
#  14%|█▍        | 1/7 [00:02<00:15,  2.65s/it]
# data_i shape: (2225, 256, 32)
# 100%|██████████| 7/7 [00:03<00:00,  2.30it/s]
# data_i shape: (2255, 256, 32)
# data_i shape: (1159, 256, 32)
# data_i shape: (2297, 256, 32)
# data_i shape: (2235, 256, 32)
# data_i shape: (2281, 256, 32)
# data_i shape: (2165, 256, 32)
# Read in data shape: (14617, 256, 32)
# Getting amplitudes...
# 100%|██████████| 7/7 [00:00<00:00, 16.14it/s]
# Fitting time: 0.4865579605102539 s
# Processed chunk 1/2
# 100%|██████████| 1/1 [00:00<00:00,  4.86it/s]
# data_i shape: (307, 256, 32)
# Read in data shape: (307, 256, 32)
# Getting amplitudes...
# 100%|██████████| 7/7 [00:00<00:00, 829.64it/s]
# Fitting time: 0.07049989700317383 s
# Processed chunk 2/2
# Getting hits...
# Reading in data...
# 100%|██████████| 7/7 [00:03<00:00,  2.27it/s]
# data_i shape: (2271, 256, 32)
# data_i shape: (2219, 256, 32)
# data_i shape: (1260, 256, 32)
# data_i shape: (2251, 256, 32)
# data_i shape: (2255, 256, 32)
# data_i shape: (2230, 256, 32)
# data_i shape: (2255, 256, 32)
# Read in data shape: (14741, 256, 32)
# Getting amplitudes...
# 100%|██████████| 7/7 [00:00<00:00, 16.62it/s]
# Fitting time: 0.4594876766204834 s
# Processed chunk 1/2
# 100%|██████████| 1/1 [00:01<00:00,  1.25s/it]
# data_i shape: (2207, 256, 32)
# Read in data shape: (2207, 256, 32)
# Getting amplitudes...
# 100%|██████████| 7/7 [00:00<00:00, 213.24it/s]
# Fitting time: 0.09071207046508789 s
# Processed chunk 2/2
# Getting hits...
# Reading in data...
#  14%|█▍        | 1/7 [00:02<00:16,  2.75s/it]
# data_i shape: (2233, 256, 32)
# 100%|██████████| 7/7 [00:03<00:00,  2.14it/s]
# data_i shape: (2302, 256, 32)
# data_i shape: (2273, 256, 32)
# data_i shape: (2249, 256, 32)
# data_i shape: (2257, 256, 32)
# data_i shape: (2269, 256, 32)
# data_i shape: (2206, 256, 32)
# Read in data shape: (15789, 256, 32)
# Getting amplitudes...
# 100%|██████████| 7/7 [00:00<00:00, 15.65it/s]
# Fitting time: 0.4958467483520508 s
# Processed chunk 1/2
# 100%|██████████| 1/1 [00:00<00:00,  1.63it/s]
# data_i shape: (1163, 256, 32)
# Read in data shape: (1163, 256, 32)
# Getting amplitudes...
# 100%|██████████| 7/7 [00:00<00:00, 691.74it/s]
# Fitting time: 0.07627034187316895 s
# Processed chunk 2/2
# Getting hits...
# Reading in data...
# 100%|██████████| 7/7 [00:02<00:00,  2.36it/s]
# data_i shape: (2247, 256, 32)
# data_i shape: (1294, 256, 32)
# data_i shape: (2204, 256, 32)
# data_i shape: (2210, 256, 32)
# data_i shape: (2233, 256, 32)
# data_i shape: (2234, 256, 32)
# data_i shape: (2317, 256, 32)
# Read in data shape: (14739, 256, 32)
# Getting amplitudes...
# 100%|██████████| 7/7 [00:00<00:00, 16.35it/s]
# Fitting time: 0.4830007553100586 s
# Processed chunk 1/2
# 100%|██████████| 1/1 [00:01<00:00,  1.21s/it]
# data_i shape: (2207, 256, 32)
# Read in data shape: (2207, 256, 32)
# Getting amplitudes...
# 100%|██████████| 7/7 [00:00<00:00, 169.56it/s]
# Fitting time: 0.09393000602722168 s
# Processed chunk 2/2
# Getting hits...
# Reading in data...
#  14%|█▍        | 1/7 [00:02<00:16,  2.74s/it]
# data_i shape: (2304, 256, 32)
# 100%|██████████| 7/7 [00:03<00:00,  2.16it/s]
# data_i shape: (2229, 256, 32)
# data_i shape: (2338, 256, 32)
# data_i shape: (2307, 256, 32)
# data_i shape: (2227, 256, 32)
# data_i shape: (2196, 256, 32)
# data_i shape: (2248, 256, 32)
# Read in data shape: (15849, 256, 32)
# Getting amplitudes...
# 100%|██████████| 7/7 [00:00<00:00, 15.86it/s]
# Fitting time: 0.48447299003601074 s
# Processed chunk 1/2
# 100%|██████████| 1/1 [00:00<00:00,  1.36it/s]
# data_i shape: (1383, 256, 32)
# Read in data shape: (1383, 256, 32)
# Getting amplitudes...
# 100%|██████████| 7/7 [00:00<00:00, 424.02it/s]
# Fitting time: 0.07744526863098145 s
# Processed chunk 2/2
# Getting hits...
# Reading in data...
#  14%|█▍        | 1/7 [00:02<00:16,  2.69s/it]
# data_i shape: (2248, 256, 32)
#  43%|████▎     | 3/7 [00:03<00:03,  1.32it/s]
# data_i shape: (2265, 256, 32)
# data_i shape: (2268, 256, 32)
# data_i shape: (2251, 256, 32)
# 100%|██████████| 7/7 [00:03<00:00,  2.24it/s]
# data_i shape: (1494, 256, 32)
# data_i shape: (2306, 256, 32)
# data_i shape: (2313, 256, 32)
# Read in data shape: (15145, 256, 32)
# Getting amplitudes...
# 100%|██████████| 7/7 [00:00<00:00, 16.22it/s]
# Fitting time: 0.46809816360473633 s
# Processed chunk 1/2
# 100%|██████████| 1/1 [00:01<00:00,  1.26s/it]
# data_i shape: (2289, 256, 32)
# Read in data shape: (2289, 256, 32)
# Getting amplitudes...
# 100%|██████████| 7/7 [00:00<00:00, 214.47it/s]
# Fitting time: 0.0959157943725586 s
# Processed chunk 2/2
# Getting hits...
# Reading in data...
#  14%|█▍        | 1/7 [00:02<00:16,  2.76s/it]
# data_i shape: (1689, 256, 32)
#  29%|██▊       | 2/7 [00:03<00:07,  1.54s/it]
# data_i shape: (2288, 256, 32)
# data_i shape: (2272, 256, 32)
# 100%|██████████| 7/7 [00:03<00:00,  1.86it/s]
# data_i shape: (2284, 256, 32)
# data_i shape: (2245, 256, 32)
# data_i shape: (2357, 256, 32)
# data_i shape: (2293, 256, 32)
# Read in data shape: (15428, 256, 32)
# Getting amplitudes...
# 100%|██████████| 7/7 [00:00<00:00, 15.53it/s]
# Fitting time: 0.4991276264190674 s
# Processed chunk 1/2
# 100%|██████████| 1/1 [00:01<00:00,  1.47s/it]
# data_i shape: (2354, 256, 32)
# Read in data shape: (2354, 256, 32)
# Getting amplitudes...
# 100%|██████████| 7/7 [00:00<00:00, 301.67it/s]
# Fitting time: 0.09033751487731934 s
# Processed chunk 2/2
# Getting hits...
# Reading in data...
# 100%|██████████| 7/7 [00:05<00:00,  1.23it/s]
# data_i shape: (2328, 256, 32)
# data_i shape: (2305, 256, 32)
# data_i shape: (2210, 256, 32)
# data_i shape: (2324, 256, 32)
# data_i shape: (2305, 256, 32)
# data_i shape: (2245, 256, 32)
# data_i shape: (1693, 256, 32)
# Read in data shape: (15410, 256, 32)
# Getting amplitudes...
# 100%|██████████| 7/7 [00:00<00:00, 11.81it/s]
# Fitting time: 0.671431303024292 s
# Processed chunk 1/2
# 100%|██████████| 1/1 [00:01<00:00,  1.66s/it]
# data_i shape: (2314, 256, 32)
# Read in data shape: (2314, 256, 32)
# Getting amplitudes...
# 100%|██████████| 7/7 [00:00<00:00, 156.06it/s]
# Fitting time: 0.10193872451782227 s
# Processed chunk 2/2
# Getting hits...
# Reading in data...
# 100%|██████████| 7/7 [00:03<00:00,  2.05it/s]
# data_i shape: (2300, 256, 32)
# data_i shape: (2314, 256, 32)
# data_i shape: (2257, 256, 32)
# data_i shape: (2250, 256, 32)
# data_i shape: (2304, 256, 32)
# data_i shape: (2351, 256, 32)
# data_i shape: (2244, 256, 32)
# Read in data shape: (16020, 256, 32)
# Getting amplitudes...
# 100%|██████████| 7/7 [00:00<00:00, 15.98it/s]
# Fitting time: 0.5080652236938477 s
# Processed chunk 1/2
# 100%|██████████| 1/1 [00:00<00:00,  1.20it/s]
# data_i shape: (1635, 256, 32)
# Read in data shape: (1635, 256, 32)
# Getting amplitudes...
# 100%|██████████| 7/7 [00:00<00:00, 399.18it/s]
# Fitting time: 0.0799868106842041 s
# Processed chunk 2/2
# Getting hits...
# Reading in data...
# 100%|██████████| 7/7 [00:03<00:00,  1.92it/s]
# data_i shape: (2313, 256, 32)
# data_i shape: (2252, 256, 32)
# data_i shape: (2239, 256, 32)
# data_i shape: (1702, 256, 32)
# data_i shape: (2296, 256, 32)
# data_i shape: (2359, 256, 32)
# data_i shape: (2265, 256, 32)
# Read in data shape: (15426, 256, 32)
# Getting amplitudes...
# 100%|██████████| 7/7 [00:00<00:00, 15.46it/s]
# Fitting time: 0.50156569480896 s
# Processed chunk 1/2
# 100%|██████████| 1/1 [00:01<00:00,  1.43s/it]
# data_i shape: (2323, 256, 32)
# Read in data shape: (2323, 256, 32)
# Getting amplitudes...
# 100%|██████████| 7/7 [00:00<00:00, 141.80it/s]
# Fitting time: 0.11229538917541504 s
# Processed chunk 2/2
# Getting hits...
# /local/home/dn277127/PycharmProjects/saclay_micromegas/DreamData.py:525: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   fig, ax = plt.subplots()
# Reading in data...
# 100%|██████████| 7/7 [00:05<00:00,  1.27it/s]
# data_i shape: (2256, 256, 32)
# data_i shape: (2210, 256, 32)
# data_i shape: (2120, 256, 32)
# data_i shape: (2120, 256, 32)
# data_i shape: (2201, 256, 32)
# data_i shape: (2154, 256, 32)
# data_i shape: (2144, 256, 32)
# Read in data shape: (15205, 256, 32)
# Getting amplitudes...
# 100%|██████████| 7/7 [00:00<00:00, 13.70it/s]
# Fitting time: 0.5807499885559082 s
# Processed chunk 1/1
# Getting hits...
# Reading in data...
# 100%|██████████| 7/7 [00:03<00:00,  2.01it/s]
# data_i shape: (2146, 256, 32)
# data_i shape: (769, 256, 32)
# data_i shape: (2234, 256, 32)
# data_i shape: (2187, 256, 32)
# data_i shape: (2140, 256, 32)
# data_i shape: (2147, 256, 32)
# data_i shape: (2159, 256, 32)
# Read in data shape: (13782, 256, 32)
# Getting amplitudes...
# 100%|██████████| 7/7 [00:00<00:00, 16.65it/s]
# Fitting time: 0.4843616485595703 s
# Processed chunk 1/2
# 100%|██████████| 1/1 [00:01<00:00,  1.28s/it]
# data_i shape: (2207, 256, 32)
# Read in data shape: (2207, 256, 32)
# Getting amplitudes...
# 100%|██████████| 7/7 [00:00<00:00, 151.82it/s]
# Fitting time: 0.08171486854553223 s
# Processed chunk 2/2
# Getting hits...
# Reading in data...
#  57%|█████▋    | 4/7 [00:02<00:01,  1.78it/s]
# data_i shape: (2183, 256, 32)
# data_i shape: (1090, 256, 32)
# data_i shape: (2197, 256, 32)
# data_i shape: (2157, 256, 32)
# data_i shape: (2213, 256, 32)
# 100%|██████████| 7/7 [00:02<00:00,  2.38it/s]
# data_i shape: (2246, 256, 32)
# data_i shape: (2121, 256, 32)
# Read in data shape: (14207, 256, 32)
# Getting amplitudes...
# 100%|██████████| 7/7 [00:00<00:00, 15.35it/s]
# Fitting time: 0.5314643383026123 s
# Processed chunk 1/2
# 100%|██████████| 1/1 [00:01<00:00,  1.39s/it]
# data_i shape: (2180, 256, 32)
# Read in data shape: (2180, 256, 32)
# Getting amplitudes...
# 100%|██████████| 7/7 [00:00<00:00, 207.71it/s]
# Fitting time: 0.10596632957458496 s
# Processed chunk 2/2
# Getting hits...
# Reading in data...
#  14%|█▍        | 1/7 [00:02<00:16,  2.79s/it]
# data_i shape: (2185, 256, 32)
# 100%|██████████| 7/7 [00:03<00:00,  2.27it/s]
# data_i shape: (2194, 256, 32)
# data_i shape: (994, 256, 32)
# data_i shape: (2197, 256, 32)
# data_i shape: (2159, 256, 32)
# data_i shape: (2134, 256, 32)
# data_i shape: (2147, 256, 32)
# Read in data shape: (14010, 256, 32)
# Getting amplitudes...
# 100%|██████████| 7/7 [00:00<00:00, 16.82it/s]
# Fitting time: 0.457507848739624 s
# Processed chunk 1/2
# 100%|██████████| 1/1 [00:01<00:00,  1.28s/it]
# data_i shape: (2161, 256, 32)
# Read in data shape: (2161, 256, 32)
# Getting amplitudes...
# 100%|██████████| 7/7 [00:00<00:00, 257.52it/s]
# Fitting time: 0.09359240531921387 s
# Processed chunk 2/2
# Getting hits...
# Reading in data...
# 100%|██████████| 7/7 [00:03<00:00,  2.10it/s]
# data_i shape: (2136, 256, 32)
# data_i shape: (2177, 256, 32)
# data_i shape: (2146, 256, 32)
# data_i shape: (2095, 256, 32)
# data_i shape: (2218, 256, 32)
# data_i shape: (929, 256, 32)
# data_i shape: (2190, 256, 32)
# Read in data shape: (13891, 256, 32)
# Getting amplitudes...
# 100%|██████████| 7/7 [00:00<00:00, 17.99it/s]
# Fitting time: 0.4355130195617676 s
# Processed chunk 1/2
# 100%|██████████| 1/1 [00:01<00:00,  1.15s/it]
# data_i shape: (2126, 256, 32)
# Read in data shape: (2126, 256, 32)
# Getting amplitudes...
# 100%|██████████| 7/7 [00:00<00:00, 329.31it/s]
# Fitting time: 0.08706378936767578 s
# Processed chunk 2/2
# Getting hits...

# %%
fig, ax = plt.subplots()
ax.errorbar(drift_vs, sigmas_x, yerr=sigma_x_errs, fmt='o', label='X Strips')
ax.errorbar(drift_vs, sigmas_y, yerr=sigma_y_errs, fmt='o', label='Y Strips')
ax.set_xlabel('Drift Voltage [V]')
ax.set_ylabel('Time Resolution [ns]')
ax.set_title(f'Time Resolution vs Drift Voltage for {detector}')
ax.legend()
